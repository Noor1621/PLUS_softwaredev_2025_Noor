# %% [markdown]
# # Assignment A4 – Geospatial Visualization with Matplotlib
#
# This notebook demonstrates how to use geospatial visualization functions from an external Python module (`geospatial_utils.py`).
# We'll use real coordinate and shapefile examples to create simple maps using the `matplotlib` library.

# %%
from geospatial_utils import plot_coordinates, plot_simple_polygon, plot_population_choropleth

# %%
# Example 1: Plotting coordinates
coords = [(13.04, 47.82), (13.05, 47.81), (13.06, 47.83)]
plot_coordinates(coords, title="Coordinate Plot")

# %% [markdown]
# ## Example 2: Plotting a Simple Polygon
#
# Here we define a polygon using longitude/latitude points and visualize it.

# %%
polygon = [(13.04, 47.82), (13.05, 47.81), (13.06, 47.83), (13.04, 47.82)]  # Closing the polygon
plot_simple_polygon(polygon, title="Simple Polygon Example")

# %% [markdown]
# ## Example 3: Mock Choropleth Map
#
# This is a mock example of a population choropleth using polygon shapes and simulated data.

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import numpy as np

# Mock polygons
polygons = [
    [(13.00, 47.80), (13.02, 47.80), (13.02, 47.82), (13.00, 47.82)],
    [(13.03, 47.80), (13.05, 47.80), (13.05, 47.82), (13.03, 47.82)],
    [(13.00, 47.83), (13.02, 47.83), (13.02, 47.85), (13.00, 47.85)]
]
populations = [150, 300, 450]

plot_population_choropleth(polygons, populations, title="Mock Population Choropleth")
